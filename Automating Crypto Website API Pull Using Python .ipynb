# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '56e9ec8f-2d24-4d81-945b-7f57cb7764a5',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
import pandas as pd
pd.json_normalize(data['data'])
# Out:
#          id                      name  symbol                      slug  \
# 0         1                   Bitcoin     BTC                   bitcoin
# 1      1027                  Ethereum     ETH                  ethereum
# 2       825               Tether USDt    USDT                    tether
# 3      1839                       BNB     BNB                       bnb
# 4      5426                    Solana     SOL                    solana
# ...     ...                       ...     ...                       ...
# 4995  29300                    Marvin  MARVIN                  marvin-2
# 4996  22471             BLUEART TOKEN     BLA             blueart-token
# 4997  15959            Vader Protocol   VADER            vader-protocol
# 4998  21912           New World Order   STATE           new-world-order
# 4999  31570  simpson in a memes world     SEW  simpson-in-a-memes-world
#
#       num_market_pairs                date_added  \
# 0                11104  2010-07-13T00:00:00.000Z
# ...

# %%
pd.json_normalize(data['data'])
# Out:
#          id                      name  symbol                      slug  \
# 0         1                   Bitcoin     BTC                   bitcoin
# 1      1027                  Ethereum     ETH                  ethereum
# 2       825               Tether USDt    USDT                    tether
# 3      1839                       BNB     BNB                       bnb
# 4      5426                    Solana     SOL                    solana
# ...     ...                       ...     ...                       ...
# 4995  29300                    Marvin  MARVIN                  marvin-2
# 4996  22471             BLUEART TOKEN     BLA             blueart-token
# 4997  15959            Vader Protocol   VADER            vader-protocol
# 4998  21912           New World Order   STATE           new-world-order
# 4999  31570  simpson in a memes world     SEW  simpson-in-a-memes-world
#
#       num_market_pairs                date_added  \
# 0                11104  2010-07-13T00:00:00.000Z
# ...

# %%
import pandas as pd
#see all available rows
pd.set_option('display.max_columns', None)

# %%
df=pd.json_normalize(data['data'])
df['timestamp']=pd.to_datetime('now')
df
# Out:
#          id                      name  symbol                      slug  \
# 0         1                   Bitcoin     BTC                   bitcoin
# 1      1027                  Ethereum     ETH                  ethereum
# 2       825               Tether USDt    USDT                    tether
# 3      1839                       BNB     BNB                       bnb
# 4      5426                    Solana     SOL                    solana
# ...     ...                       ...     ...                       ...
# 4995  29300                    Marvin  MARVIN                  marvin-2
# 4996  22471             BLUEART TOKEN     BLA             blueart-token
# 4997  15959            Vader Protocol   VADER            vader-protocol
# 4998  21912           New World Order   STATE           new-world-order
# 4999  31570  simpson in a memes world     SEW  simpson-in-a-memes-world
#
#       num_market_pairs                date_added  \
# 0                11104  2010-07-13T00:00:00.000Z
# ...

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

def api_runner():
    global df      
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'5000',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '56e9ec8f-2d24-4d81-945b-7f57cb7764a5',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    df2=pd.json_normalize(data['data'])
    df2['timestamp']=pd.to_datetime('now')
    #df_append = pd.DataFrame(df2)
    df=pd.concat([df,df2])
 
    if not os.path.isfile(r"C:\Users\mfuazi88\Desktop\DATA Analyst\API.csv"):
        df.to_csv(r"C:\Users\mfuazi88\Desktop\DATA Analyst\API.csv",header='column_names')
    else:
        df.to_csv(r"C:\Users\mfuazi88\Desktop\DATA Analyst\API.csv", mode='a' header=False)

# %%
import os
from time import time
from time import sleep

for i in range(200):
    sleep(30) #sleep for 30 seconds
    api_runner()
    print("API Runner completed")
    if i==2:
        break
# Out:
# API Runner completed
# API Runner completed
# API Runner completed

# %%
df30=pd.read_csv(r"C:\Users\mfuazi88\Desktop\DATA Analyst\API.csv")
df30
# Out:
#        Unnamed: 0     id               name  symbol               slug  \
# 0               0      1            Bitcoin     BTC            bitcoin
# 1               1   1027           Ethereum     ETH           ethereum
# 2               2    825        Tether USDt    USDT             tether
# 3               3   1839                BNB     BNB                bnb
# 4               4   5426             Solana     SOL             solana
# ...           ...    ...                ...     ...                ...
# 29995        4995  29876          KunaiKash   KUNAI          kunaikash
# 29996        4996  30654   Giga Cat on Base    GCAT   giga-cat-on-base
# 29997        4997  28512          DumbMoney     GME          dumbmoney
# 29998        4998  27000            Nurcoin     NUR            nurcoin
# 29999        4999  15013  ReSource Protocol  SOURCE  resource-protocol
#
#        num_market_pairs                date_added  \
# 0                 11104  2010-07-13T00:00:00.000Z
# ...

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

def api_runner():
    global df      
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'5000',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '56e9ec8f-2d24-4d81-945b-7f57cb7764a5',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    df=pd.json_normalize(data['data'])
    df['timestamp']=pd.to_datetime('now')
    df
 
    if not os.path.isfile(r"C:\Users\mfuazi88\Desktop\DATA Analyst\API.csv"):
        df.to_csv(r"C:\Users\mfuazi88\Desktop\DATA Analyst\API.csv", header='column_names')
    else:
        df.to_csv(r"C:\Users\mfuazi88\Desktop\DATA Analyst\API.csv", mode='a', header=False)

# %%
pd.options.display.float_format = '{:,.2f}'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pd.options.display.float_format = '{:,.2f}'
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:224, in DictWrapper.__setattr__(self, key, val)
#     221 # you can't set new keys
#     222 # can you can't overwrite subtrees
#     223 if key in self.d and not isinstance(self.d[key], dict):
# --> 224     _set_option(prefix, val)
#     225 else:
#     226     raise OptionError("You can only set the value of existing options")
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:160, in _set_option(*args, **kwargs)
#     158 o = _get_registered_option(key)
#     159 if o and o.validator:
# --> 160     o.validator(v)
#     162 # walk the nested dict
#     163 root, k = _get_root(key)
#
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' %x)
df30
# Out:
#        Unnamed: 0     id               name  symbol               slug  \
# 0               0      1            Bitcoin     BTC            bitcoin
# 1               1   1027           Ethereum     ETH           ethereum
# 2               2    825        Tether USDt    USDT             tether
# 3               3   1839                BNB     BNB                bnb
# 4               4   5426             Solana     SOL             solana
# ...           ...    ...                ...     ...                ...
# 29995        4995  29876          KunaiKash   KUNAI          kunaikash
# 29996        4996  30654   Giga Cat on Base    GCAT   giga-cat-on-base
# 29997        4997  28512          DumbMoney     GME          dumbmoney
# 29998        4998  27000            Nurcoin     NUR            nurcoin
# 29999        4999  15013  ReSource Protocol  SOURCE  resource-protocol
#
#        num_market_pairs                date_added  \
# 0                 11104  2010-07-13T00:00:00.000Z
# ...
